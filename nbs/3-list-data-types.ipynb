# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint, params={'duration':'5 minutes', 'pages':[]})

print('ok', response.ok)

if response.ok :
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'avg_duration': 148.44230769230768,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 104,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 149.578125,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 128,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 134.90721649484536,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 97,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 131.7157894736842,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 95,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 155.79166666666666,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 96,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 146.79761904761904,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 84,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 156.61111111111111,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 90,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 154.57142857142858,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 91,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 143.54,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 100,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 148.6530612244898,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 98,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 151.60509554140128,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 157,
#   'operating_system': 'IOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 167.10852713178295,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 129,
#   'operating_system': 'IOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 141.81451612903226,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 124,
#   'operating_system': 'IOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 144.84251968503938,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 127,
#   'operating_system': 'IOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 168.97794117647058,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 136,
#   'operating_system': 'IOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 143.0252100840336,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 119,
#   'operating_system': 'IOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 148.40151515151516,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 132,
#   'operating_system': 'IOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 142.74107142857142,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 112,
#   'operating_system': 'IOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 158.33070866141733,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 127,
#   'operating_system': 'IOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 134.9928057553957,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 139,
#   'operating_system': 'IOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 153.0,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 218,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 164.45416666666668,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 240,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 145.97549019607843,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 204,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 154.06451612903226,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 217,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 149.69811320754718,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 212,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 145.38695652173914,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 230,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 142.99606299212599,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 254,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 135.643216080402,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 199,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 150.56632653061226,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 196,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 153.41013824884791,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 217,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 153.9371727748691,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 191,
#   'operating_system': 'MacOs',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 149.68,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 175,
#   'operating_system': 'MacOs',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 153.31288343558282,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 163,
#   'operating_system': 'MacOs',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 147.15816326530611,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 196,
#   'operating_system': 'MacOs',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 148.1153846153846,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 156,
#   'operating_system': 'MacOs',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 163.46067415730337,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 178,
#   'operating_system': 'MacOs',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 150.81564245810057,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 179,
#   'operating_system': 'MacOs',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 148.49214659685865,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 191,
#   'operating_system': 'MacOs',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 143.07843137254903,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 153,
#   'operating_system': 'MacOs',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 145.13227513227514,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 189,
#   'operating_system': 'MacOs',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 142.11428571428573,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 35,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 135.26415094339623,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 53,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 138.17021276595744,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 47,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 152.71929824561403,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 57,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 151.32258064516128,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 62,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 141.6909090909091,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 55,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 148.0212765957447,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 47,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 141.82051282051282,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 39,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 136.06382978723406,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 47,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 158.3095238095238,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 42,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 148.86449864498644,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 369,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 157.88958990536278,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 317,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 157.5670731707317,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 328,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 155.46504559270517,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 329,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 163.85342019543975,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 307,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 147.88888888888889,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 333,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 145.95348837209303,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 301,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 155.67741935483872,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 341,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 154.626582278481,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 316,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 148.710843373494,
#   'bucket': '2025-06-12T03:00:00Z',
#   'count': 332,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''}]

# %%
detail_path = "/api/events/12"
detail_endpoint = f"{base_url}{detail_path}"

detail_response = requests.get(detail_endpoint)
print('ok', detail_response.status_code)
if detail_response.ok :
    data = detail_response.json()
    pprint(data)
# Out:
# ok 200
# {'duration': 50,
#  'id': 12,
#  'ip_address': '149.91.181.49',
#  'page': '/blog',
#  'referrer': 'https://google.com',
#  'session_id': 'ac571663-d75f-46c4-aae5-9d6e2d6cc8fb',
#  'time': '2025-06-12T03:03:25.566584Z',
#  'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1) AppleWebKit/531.23.7 '
#                '(KHTML, like Gecko) Version/4.1 Safari/531.23.7'}
